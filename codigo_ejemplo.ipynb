# %% [markdown]
# ## Codigo ejemplo

# %% [markdown]
# ```javascript
# const div = document.getElementById("miDiv");
#
# div.addEventListener("mouseover", function () {
#   div.style.borderColor = "#D1664F";
#
# )}
# ```
