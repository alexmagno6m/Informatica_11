# %% [markdown]
# ### Asignatura Informatica - Grado 11
# __Clase:__ Tablas dinamicas y dasdhboards<br>
# __Profesor:Alexander Acevedo Gomez__<br>
# Ingeniero de Sistemas - Universidad Nacional de Colombia <br>
# Magister en Modelado y Simulacion por Computador - Universidad Jorge Tadeo Lozano <br>
# __Telegram: @Alex6m__

# %% [markdown]
# # Ejemplo tablas dinamicas

# %% [markdown]
# Genere la estructura de archivos en su computador asignado"

# %% [markdown]
# ```
# └── Informatica 11/
#     └── Su curso/
#         └── Su nombre/
#             └── Dashboard/
#                 └── Actividad 1/
# ```

# %% [markdown]
# 1. Copie la tabla correspondiente a su curso segun las indicaciones dadas en clase
# 2. Realice las operaciones segun las instrucciones.
# 3. Al terminar escriba lo siguiente para obtener el sello por la realizacion de este ejemplo:

# %% [markdown]
# - Competencia: 1
# - Ambito conceptual: Tablas dinamicas y segmentacion de datos
# - Objetivo: Convertir correctamente una tabla de formato raw a dinamica para el analisis de datos comprimidos en segmentadores.
