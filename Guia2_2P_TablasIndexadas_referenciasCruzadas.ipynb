# %% [markdown]
# ### Asignatura Informatica - Grado 11
# __Clase:__ Tablas indexadas y referencias cruzadas<br>
# __Profesor:Alexander Acevedo Gomez__<br>
# Ingeniero de Sistemas - Universidad Nacional de Colombia <br>
# Magister en Modelado y Simulacion por Computador - Universidad Jorge Tadeo Lozano <br>
# __Telegram: @Alex6m__

# %% [markdown]
# # Tablas indexadas
# ## Conceptos Basicos
# Son aquellas agrupaciones de elementos como: figuras, graficos, ecuaciones, ilustraciones y las propias tablas que aparecen a lo largo de un documento profesional, academico o de caracter investigativo
#
# > ### Tablas de ilustraciones
# >
# > Una ilustracion es producto de un diseño artifical, el cual pudo ser eleborado en forma manual, herramientas digitales, o una combinacion de ambos. Dentro de esta categoria entran imagenes de comics, cuadros artisticos, pinturas, etc.
# >
# > ### Tablas de imagenes
# >
# > Corresponde a las fotografias propiamente dichas del __mundo real__, manipuladas o no, que son captadas por lentes de camaras de aparatos aptos para esa labor.
# >
# > ### Tablas de figuras
# >
# > Son diagramas elaborados con el fin de complementar la informacion al texto, contribuir a su explicacion, aclarar conceptos o modelar sistemas, entran en esta categoria los diagramas de flujo, mapas mentales, diagramas de nodos, graficos de funciones matematicas o cientificas.
# >
# > ### Tablas de ecuaciones
# >
# > Toda expresion matematica o cientifica como una ecuacion, funcion, sumatoria o la notacion numerica y simbolica especial debe ir agrupada en esta categoria.

# %% [markdown]
# ## Procedimiento para referenciar tablas indexadas
# Como se ha visto hasta el momento, para indexar una tabla primero debemos referenciarla con el correspondiente titulo, es conocido en Word como rotulo o etiqueta.
# > ### Insertar el titulo del elemento a indexar en la tabla
# > - Se hace en el menu referencias, seleccionado _insertar titulo_.
# > - Si el titulo no se ha creado, se debe proceder a agregar el correspondiente a la categoria que se necesite.
# > - Se debe cambiar el estilo para que corresponda con el resto del documento.
# >
# > ### Generar la tabla indexada
# > Las tablas indexadas deben ubicarse inmediatamente despues de la tabla de contenido. Una vez alli siga los siguientes pasos:
# > - Haga clic en referencias, _insertar tabla de ilustraciones_
# > - Seleccione la etiqueta o rutulo de la categoria de la tabla a indexar
# > - Haga clic en aceptar
# > - Corrija el estilo para que se ajuste al resto del documento.

# %% [markdown]
# # Referencias Cruzadas
#
# ## Concepto
# Son enlaces de elementos referenciados en el documento que se citan en un lugar usualmente distitno a donde esta ubicado tal elemento.

# %% [markdown]
# ## Procedimiento para crear referencias cruzadas
# Lo primero es haber creado previamente el elemento a referenciar, entiendase: titulos, tablas de contenido, elementos indexados.
# > - Se selecciona el texto correspondiente, en general debe mencionar explicitamente el elemento a referenciar, por ejemplo: _vease tabla 1_.
# > - En el menu referencias, se selecciona _referencia cruzada_.
# > - En la ventana se escoge la categoria del elemento a referenciar, por ejemplo: titulo, ilustraciones, imagenes, etc.
# > - En la lista se selecciona el elemento en especifico.

# %% [markdown]
# # Estilos correspondientes
# > | Estilo                 | Valor                                                   |
# |------------------------|---------------------------------------------------------|
# | Titulos de tablas indexadas               | Times New Roman, 11, Cursiva, Centrado, Negro |
# | Referencias cruzadas               | Del mismo estilo del resto del texto normal, cursiva|

# %% [markdown]
# # Actividad
# ## Parte Teorica
# > Responda las siguientes preguntas en su cuaderno:
# > 1. Segun lo leido en la guia, indique para cada una de las siguientes imagenes, que tipo de categoria de tabla indexada es (figura, ilustracion, imagen, ecuacion)
# >
# > - ![img6.jpeg](attachment:img6.jpeg)

# %% [markdown]
# > - ![img6.png](attachment:img6.png)

# %% [markdown]
# > - ![img7.jpeg](attachment:img7.jpeg)

# %% [markdown]
# > - ![img8.jpeg](attachment:img8.jpeg)

# %% [markdown]
# > - ![img9.jpeg](attachment:img9.jpeg)

# %% [markdown]
# > - ![img10.png](attachment:img10.png)

# %% [markdown]
# > 2. Explique cual es la diferencia entre titulo de contenido y titulo de rotulo.
# > 3. Indique con sus propias palabras, porque se deben incluir referencias cruzadas en los textos academicos y profesionales

# %% [markdown]
# ## Parte Practica

# %% [markdown]
# - Genere el siguiente esquema de contenido, cada titulo principal en su propia pagina:
# >
# > 1.	Introducción
# > 2.	Objetivo general
# > 3.	Objetivos Específicos
# > 4.	Justificación
# > 5.	Pregunta de Investigación
# > 6.	Estado del Arte
# > 7.	Metodología
# >> Materiales <br>
# >> Métodos <br>
# >> Resultados Preliminares <br>
# >> Discusión Preliminar <br>
# > 8.	Resultados
# >>
# >> Formulas <br>
# >> Documentacion <br>
# >> Grupo de control <br>
# >
# > 9.	Conclusiones
# > 10.	Bibliografía
# > 11.	Nota
# >
# - Seleccione un tema de su interes
# - En los titulos 4, 5 y 6 agregue una imagen desde internet, las tres relacionadas con el tema en cuestion (no obscenas, no violentas, no ofensivas)
# - En los titulos de nivel inferior del numeral 7 agregue debajo de cada uno de ellos una ilustacion en lo posible relacionada con el mismo tema.
# - En los titulos de nivel inferior del numeral 8 agregue debajo de cada uno de ellos una figura, en lo posible relacionada con el mismo tema.
# - En la conclusion, copie cuatro parrafos de internet relacionados con el tema que selecciono, agregue una referencia cruzada en cada uno de ellos de la siguiente manera:
#     - En el parrafo 1: referencia a una de las ilustraciones
#     - En el parrafo 2: referencia a una de las imagenes
#     - En el parrafo 3: referencia a dos de las figuras
# - Agregue en la primera pagina del documento la tabla de contenido
# - Agregue inmediatamente despues las tablas de imagenes, ilustraciones y figuras.
